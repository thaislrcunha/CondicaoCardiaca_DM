# %% [markdown]
# <a href="https://colab.research.google.com/github/thaislrcunha/CondicaoCardiaca_DM/blob/main/Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/thaislrcunha/CondicaoCardiaca_DM/main/UCMF_raw.csv"
df = pd.read_csv(url)

df.head()
# Out:
#    ID  Peso  Altura   IMC Atendimento        DN  IDADE Convenio   PULSOS  \
# 0   1   5.0      51  19.0    11/05/06  30/03/06   0.12       GS  Normais
# 1   2   3.5      50  14.0    25/05/05  19/05/05   0.02       GS  Normais
# 2   3   0.0       0   NaN    12/06/01  08/05/05  -4.05     SULA  Normais
# 3   4   8.1      65  19.0    15/10/09  21/04/09   0.50      NaN  Normais
# 4   7  40.0     151  18.0    14/01/08  14/08/95  12.89     SAME  Normais
#
#    PA SISTOLICA  ...            PPA NORMAL X ANORMAL      B2      SOPRO   FC  \
# 0           NaN  ...  Não Calculado          Anormal  Normal  Sistólico  112
# 1           NaN  ...  Não Calculado          Anormal  Normal    ausente  128
# 2           NaN  ...  Não Calculado          Anormal  Normal  Sistólico   88
# 3           NaN  ...  Não Calculado          Anormal  Normal    ausente   92
# 4           NaN  ...  Não Calculado          Anormal  Normal    ausente   96
#
#             HDA 1 HDA2 SEXO                      MOTIVO1  \
# ...

# %%
df.shape  # (n_linhas, n_colunas)
# Out:
# (12873, 21)

# %%
import json

# Definição das variáveis e classificações
variaveis = [
    {"Coluna": "ID", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "Identificador apenas"},
    {"Coluna": "Peso", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "racional", "Observações": "Kg"},
    {"Coluna": "Altura", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "racional", "Observações": "cm"},
    {"Coluna": "IMC", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "racional", "Observações": "kg/m^2"},
    {"Coluna": "Atendimento", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "intervalar", "Observações": "Date"},
    {"Coluna": "DN", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "intervalar", "Observações": "Date"},
    {"Coluna": "IDADE", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "racional", "Observações": "anos"},
    {"Coluna": "Convenio", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "NA"},
    {"Coluna": "PULSOS", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "NA"},
    {"Coluna": "PA SISTOLICA", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "racional", "Observações": "mmHg"},
    {"Coluna": "PA DIASTOLICA", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "racional", "Observações": "mmHg"},
    {"Coluna": "PPA", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "NA"},
    {"Coluna": "NORMAL X ANORMAL", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "Classificação binária"},
    {"Coluna": "B2", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "NA"},
    {"Coluna": "SOPRO", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "Presença/ausência"},
    {"Coluna": "FC", "Tipo": "numérico", "Natureza": "quantitativo", "Escala": "racional", "Observações": "bpm"},
    {"Coluna": "HDA 1", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "NA"},
    {"Coluna": "HDA2", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "NA"},
    {"Coluna": "SEXO", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "M/F"},
    {"Coluna": "MOTIVO1", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "N da categoria"},
    {"Coluna": "MOTIVO2", "Tipo": "categórico", "Natureza": "qualitativo", "Escala": "nominal", "Observações": "N da categoria"}
]

dicionario = pd.DataFrame(variaveis)

print(" DICIONÁRIO DE DADOS ")
display(dicionario)

# Salvar em TXT
with open("dicionario_dados.txt", "w", encoding="utf-8") as f:
    for v in variaveis:
        f.write(json.dumps(v, ensure_ascii=False) + "\n")
# Out:
#  DICIONÁRIO DE DADOS
#               Coluna        Tipo      Natureza      Escala  \
# 0                 ID  categórico   qualitativo     nominal
# 1               Peso    numérico  quantitativo    racional
# 2             Altura    numérico  quantitativo    racional
# 3                IMC    numérico  quantitativo    racional
# 4        Atendimento    numérico  quantitativo  intervalar
# 5                 DN    numérico  quantitativo  intervalar
# 6              IDADE    numérico  quantitativo    racional
# 7           Convenio  categórico   qualitativo     nominal
# 8             PULSOS  categórico   qualitativo     nominal
# 9       PA SISTOLICA    numérico  quantitativo    racional
# 10     PA DIASTOLICA    numérico  quantitativo    racional
# 11               PPA  categórico   qualitativo     nominal
# 12  NORMAL X ANORMAL  categórico   qualitativo     nominal
# 13                B2  categórico   qualitativo     nominal
# ...
